# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhananjay0705/Statistics/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Calculating Mean

# %% [markdown]
# Method 1 - Manual Calculation

# %%
population = [150,160,170,165,155]
sample = [150,170,165]

pop_mean = sum(population)/len(population)
sample_mean = sum(sample)/len(sample)

print("population mean is : ",pop_mean)
print("Sample mean is : ",sample_mean)
# Out:
# population mean is :  160.0
# Sample mean is :  161.66666666666666

# %% [markdown]
# Method 2 - using numpy library

# %%
import numpy as np

data = (85,90,78,88,95)

airthmatic_mean = np.mean(data)
print("airthmatic mean is : ",airthmatic_mean)
# Out:
# airthmatic mean is :  87.2

# %% [markdown]
# Method 3 - using Statistics

# %%
import statistics as stats

var = [10,20,30,40,50]

stats_mean = stats.mean(var)

print("The ,mean is : ",stats_mean)
# Out:
# The ,mean is :  30

# %% [markdown]
# DATASET

# %%
import seaborn as sns
import numpy as np

iris = sns.load_dataset('iris')
iris.head()

mean_sepal_length = np.mean(iris['sepal_length'])
print("The mean of sepal length is : ",mean_sepal_length)
# Out:
# The mean of sepal length is :  5.843333333333334

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# MEDIAN

# %% [markdown]
# Method 1 - numpy library

# %%
data = [10,20,30,40,50]
median = np.median(data)
print("The median is :",median)
# Out:
# The median is : 30.0

# %% [markdown]
# METHOD 2 - Statistics

# %%
import statistics as stats

data = [10,20,30,40,50]
median = stats.median(data)
print("The median is :",median)
# Out:
# The median is : 30

# %% [markdown]
# Method 3 - Pandas

# %%
import pandas as pd

df = pd.DataFrame({
    'values':[10,20,30,40,50]
})
print(df)

median_pandas = df['values'].median()
print("The median is :",median_pandas)
# Out:
#    values
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50
# The median is : 30.0

# %% [markdown]
# DATA SET

# %%
import seaborn as sns
import numpy as np

iris = sns.load_dataset('iris')
iris.head()

median = np.median(iris['sepal_length'])
print("The median of sepal length is :",median)
# Out:
# The median of sepal length is : 5.8

# %% [markdown]
#   MODE

# %% [markdown]
# Method 1 - Statistics

# %%
import statistics as stats

data = [10,20,30,40,50,50]
mode = stats.mode(data)
print("The mode is :",mode)
# Out:
# The mode is : 50

# %%
import statistics as stats

data = [10,20,40,40,50,50]
mode = stats.multimode(data)
print("The mode is :",mode)
# Out:
# The mode is : [40, 50]

# %% [markdown]
# Scipy library

# %%
from scipy import stats

data = [10,20,30,40,50]
mode = stats.mode(data)
print("The mode of the data is :",mode)
# Out:
# The mode of the data is : ModeResult(mode=np.int64(10), count=np.int64(1))

# %% [markdown]
# VARIANCE

# %% [markdown]
# USING NUMPY

# %%
import numpy as np

data = [2,3,4,5,6,7,8]

sample_variance = np.var(data,ddof = 1)

print("The sample variance of data is :",sample_variance)

population_variance = np.var(data,ddof = 0)
print("The population variance of data is :",population_variance)
# Out:
# The sample variance of data is : 4.666666666666667
# The population variance of data is : 4.0

# %% [markdown]
# USING PANDAS

# %%
import pandas as pd

data = [2,3,4,5,6,7,8,9]
series = pd.Series(data)

sample_variance = series.var() ## sample variance by default
print("The sample variance is :",sample_variance)

pop_variance = series.var(ddof = 0)
print("The population variance is :",pop_variance)
# Out:
# The sample variance is : 6.0
# The population variance is : 5.25

# %% [markdown]
# USING Scipy

# %%
from scipy import stats

data = [4,5,6,7,8,8,9]

sample_variance = stats.tvar(data)
print("The sample variance is :",sample_variance)

population_variance = stats.tvar(data,ddof = 0)
print("The population variance is :",population_variance)
# Out:
# The sample variance is : 3.238095238095238
# The population variance is : 2.7755102040816326

# %% [markdown]
# STANDARD DEVIATION

# %% [markdown]
# USING numpy

# %%
import numpy as np

data = [2,3,4,5,6,7,8,9]

sample_std = np.std(data,ddof = 1) ## ddof = 1 for sample variance
print("The sample standard deviation the data is :",sample_std)

population_std = np.std(data,ddof = 0) ## ddof = 0 for population variance
print("The population standard deviation the data is :",population_std)
# Out:
# The sample standard deviation the data is : 2.449489742783178
# The population standard deviation the data is : 2.29128784747792

# %% [markdown]
# USING pandas

# %%
import pandas as pd
data = [2,3,4,5,6,7,8,9]
series = pd.Series(data)

sample_std = series.std() ## ddof = 1 for sample variance
print("The sample standard deviation is :",sample_std)

population_std = series.std(ddof = 0) ## ddof = 0 for population variance
print("The population standard deviation is :",population_std)
# Out:
# The sample standard deviation is : 2.449489742783178
# The population standard deviation is : 2.29128784747792

# %% [markdown]
# USING SCIPY

# %%
from scipy import stats
import math  ## this is import for square root

data = [2,3,4,5,6,7,8]

sample_std = math.sqrt(stats.tvar(data))
print("The sample standard deviation is :",sample_std)

pop_std = math.sqrt(stats.tvar(data,ddof =0))
print("The population standard deviation is :",pop_std)
# Out:
# The sample standard deviation is : 2.160246899469287
# The population standard deviation is : 2.0

# %% [markdown]
# DATA Representations

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

## Create a figure nad axes
fig, axs = plt.subplots(3,2,figsize = (14,12))
fig.suptitle("Histograms with KDE of various Distributions",fontsize = 16)

##Normal Distribution (Gaussian Distribution)
data_normal = np.random.normal(loc = 0,scale = 1,size = 1000) # Mean = 0, std Dev = 1
sns.histplot(data_normal,kde = True,ax=axs[0,0],color ='blue',stat = 'density',bins=30) ## kde = 0 for bar ke upper jo bana hai
axs[0,0].set_title('Normal Distribution')
axs[0,0].grid(True) ## grid means jo background me box bane hai unko bhi dikhane ke liye True

##Skewed distribution
data_right_skewed = np.random.exponential(scale=1,size=1000) ## Right skewed
data_left_skewed = np.random.exponential(scale=1,size=1000) ## left skewed

# Right skewed histogram
sns.histplot(data_right_skewed,kde = True,ax=axs[0,1],color='red',stat='density',bins = 30,label="Right Skewed")

## Left Skewed histogram
sns.histplot(data_left_skewed,kde=True,ax=axs[0,1],color='green',stat='density',bins=30,label='Left Skewed')
axs[0,1].set_title("SKEWED DISTRIBUTION")
axs[0,1].legend()
axs[0,1].grid(True)

## Uniform Distribution
data_uniform = np.random.uniform(low = 0,high=1,size = 1000) ## uniform Distribution between 0 and 1
sns.histplot(data_uniform,kde=True,ax = axs[1,0],color = 'purple',stat = 'density',bins = 30)
axs[1,0].set_title('uniform Distribution')
axs[1,0].grid(True)

## bimodel Distribution
data_bimodel = np.concatenate([np.random.normal(loc = 2,scale = 1,size=500),
                               np.random.normal(loc=2,scale = 1,size = 500)])
sns.histplot(data_bimodel,kde = True,ax= axs[1,1],color = 'orange',stat = 'density',bins = 30)
axs[1,1].set_title('biomodel Distribution')
axs[1,1].grid(True)

## Multimodel Distribution

data_multimodel = np.concatenate([
    np.random.normal(loc = -6,scale = 1,size = 500),
    np.random.normal(loc =0,scale = 1,size = 500 ),
    np.random.normal(loc = 6,scale = 1,size = 500)
])

sns.histplot(data_multimodel,kde = True,ax=axs[2,0],color = 'brown',stat = 'density',bins = 30)
axs[2,0].set_title("Multimodel Distribution")
axs[2,0].grid(True)

## Hide empty subplot

axs[2,1].axis('off')

## Adjust Layout
plt.tight_layout(rect=[0,0,1,0.96])
plt.show()

# %% [markdown]
# T Test & P Test

# %%
import numpy as np
from scipy import stats

# Step 1 : Create two random sample datasets
# suppose these are test score from two group(e.g.,group A,group B)

group_A = np.random.normal(75,10,30) # Group A with mean 75,std 10 and 30 samples
group_B = np.random.normal(80,12,30) # Group B with mean 80,std 12 and 30 samples

# Step 2 : perform an independent T  test
t_statsistics,p_value = stats.ttest_ind(group_A,group_B)

# step 3 : Display the p_values and t_statistics

print(f"T-Statistics: {t_statsistics}")
print(f"p-values:{p_value}")

# Step 4 : Interpretation based on p-value
alpha = 0.05 # significance Level
if p_value <= alpha :
  print("Reject the null hypothesis(Significance different between Groups)")
else:
  print("Fail to reject the null hypothesis(No significant difference between groups)")
# Out:
# T-Statistics: -1.0411129238454853
# p-values:0.30214362313954
# Fail to reject the null hypothesis(No significant difference between groups)

# %% [markdown]
# Z test

# %% [markdown]
# QUES - Imagine a company claims that the average weight of their product is 500 grams. we want to test if this claim is true by collecting a sample of 30 products. The sample mean is 505 grams,and the population standard deviation is 10 grams.We will conduct a Z test to see if the diffrence in the mean is significant or not.

# %%
import numpy as np
from scipy import stats

# step 1 : Define the known paprameters
population_mean = 500 # claimed population mean(mu)
sample_mean = 505 # sample mean(x bar)
population_std = 10 # population standard deviation (sigma)
sample_size = 30 # sample size(n)

# step 2 : calculate the Z- value
z_value = (sample_mean - population_mean)/(population_std/np.sqrt(sample_size))
print(f"Z-value:{z_value}")

# step3 : calculate the p-value (two-tailed test)
p_value = 2 * (1-stats.norm.cdf(abs(z_value)))
print(f"p-value:{p_value}")

# step 4: set signiicant Level
alpha = 0.05

# step 5 : Compare p-value with significance Level
if p_value < alpha :
  print("Reject the null hypothesis(significant diffrence)")
else:
  print("Fail to reject the null hypothesis(no significant difference)")
# Out:
# Z-value:2.7386127875258306
# p-value:0.0061698993205441255
# Reject the null hypothesis(significant diffrence)
